# %% [markdown]
# 1.Write a python program to create an array and covert to a
# desired dimension, as shown in picture.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

arr3 = np.arange(8,14)
arr3
arr3.reshape(2,3)
# Out:
# array([[ 8,  9, 10],
#        [11, 12, 13]])

# %%
arr=arr3.reshape(3,2)
arr
# Out:
# array([[ 8,  9],
#        [10, 11],
#        [12, 13]])

# %% [markdown]
# 2. Create an array and extract particular set of elements
# from an array as shown in the picture.
# Sliced array [9,11]

# %%
arr4 =arr[0:2,1]
arr4
# Out:
# array([ 9, 11])

# %% [markdown]
# 3. Create a dataframe as shown below.

# %%
data_dic = {'Country':['Russia','Columbia','Chile','Equadore','Nigeria'],
            'Rank':[121,40,100,130,11]}
data = pd.DataFrame(data_dic)
data
# Out:
#     Country  Rank
# 0    Russia   121
# 1  Columbia    40
# 2     Chile   100
# 3  Equadore   130
# 4   Nigeria    11

# %% [markdown]
# 4.Read the given data set and answer the following
# questions. Show the steps taken to produce your final
# answer.

# %%
#4
data = pd.read_csv('/content/diabetes_model.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# 1                       1.114   33        1
# 2                       0.278   23        1
# 3                       0.536   21        0
# 4                       0.326   47        1
# ..                        ...  ...      ...
# 609                     0.126   24        0
# 610                     0.326   22        0
# 611                     0.127   25        1
# 612                     0.647   51        0
# 613                     0.238   32        1
#
# [614 rows x 9 columns]

# %% [markdown]
# a. Display the Glucose level and the Age for the
# samples having the index ranging from 45 to 60.

# %%
#1
data.loc[45:60,['Glucose','Age']]
# Out:
#     Glucose  Age
# 45      137   21
# 46      145   70
# 47      113   22
# 48       96   27
# 49      131   26
# 50      113   21
# 51      120   34
# 52       95   24
# 53      155   46
# 54      100   46
# 55      184   49
# 56       90   29
# 57      142   61
# 58      125   27
# 59      101   26
# 60      188   22

# %% [markdown]
# b. How many patients in the data are having the blood
# pressure level above 120?

# %%
#b
data1=(data['BloodPressure']>120).sum()
data1
# Out:
# 1

# %% [markdown]
# c. Find the minimum and maximum value of insulin
# level in the data.

# %%
#c
data['Insulin'].min()
# Out:
# 0

# %%
data['Insulin'].max()
# Out:
# 846

# %% [markdown]
# d. Create a histogram of "Age".

# %%
plt.hist(data['Age'],rwidth=.6)
plt.title('Histogram of age')
# Out:
# Text(0.5, 1.0, 'Histogram of age')

# %% [markdown]
# e. Create a scatter plot of "BMI" vs "Glucose"

# %%
plt.scatter(data['BMI'],data['Glucose'],c='Green',marker="^")
plt.title('BMI VS Glucose')
plt.ylabel('Glucose')
plt.xlabel('BMI')
# Out:
# Text(0.5, 0, 'BMI')
